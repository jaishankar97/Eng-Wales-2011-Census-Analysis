# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.mixture import GaussianMixture

# %%
data = pd.read_csv('General Health by Religion by Sex by Age.csv')

# %%
data.drop(columns=['date', 'geography code'], axis=1, inplace=True)

# %%
X = data.iloc[:,1:]
Y = data.iloc[:,0]

# %%
encoder = LabelEncoder()

# %%
encoder.fit(Y)
# Out:
# LabelEncoder()

# %%
scaler = StandardScaler()

# %%
scaled_data = scaler.fit_transform(X)

# %%
gmm = GaussianMixture(n_components=3, covariance_type='spherical', random_state =0)

# %%
y_pred = gmm.fit_predict(scaled_data)

# %%
def transform_labels(predictions):

    label = {i:f"CLUSTER {i}" for i in np.unique(predictions)}
    
    return [label[i] for i in predictions]

# %%
new_labels = transform_labels(y_pred)
print(new_labels[:10])
# Out:
# ['CLUSTER 2', 'CLUSTER 1', 'CLUSTER 0', 'CLUSTER 2', 'CLUSTER 1', 'CLUSTER 0', 'CLUSTER 2', 'CLUSTER 1', 'CLUSTER 2', 'CLUSTER 1']

# %%
data['Cluster'] = new_labels

# %% [markdown]
# # Data Pre-Processing

# %%
#Check if every column name ends with "measures: value".
name_lst = data.columns

for i in range(1, len(name_lst)):
    if name_lst[i].endswith('measures: Value') == False:
        print("{} does not ends with 'measures: value'. ".format(name_lst[i]))
# Out:
# Cluster does not ends with 'measures: value'.

# %%
data.columns = data.columns.str.replace('; measures: Value', '')

# %%
data
# Out:
#                   geography  \
# 0            AL - St Albans
# 1            B - Birmingham
# 2                 BA - Bath
# 3            BB - Blackburn
# 4             BD - Bradford
# ..                      ...
# 100            CF - Cardiff
# 101  LD - Llandrindod Wells
# 102          LL - Llandudno
# 103            NP - Newport
# 104            SA - Swansea
#
#      Sex: All persons; Age: All categories: Age; General Health: All categories: General health; Religion: All categories: Religion  \
# 0                                               250427
# 1                                              1904658
# 2                                               434166
# 3                                               488917
# 4                                               578336
# ..                                                 ...
# 100                                            1005334
# 101                                              49792
# 102                                             537467
# 103                                             488368
# 104                                             730232
#
#      Sex: All persons; Age: All categories: Age; General Health: All categories: General health; Religion: Christian  \
# 0                                               146941
# 1                                              1015781
# 2                                               260769
# 3                                               294116
# 4                                               276991
# ..                                                 ...
# 100                                             530981
# 101                                              30604
# 102                                             339502
# 103                                             271818
# 104                                             430490
#
#      Sex: All persons; Age: All categories: Age; General Health: All categories: General health; Religion: Buddhist  \
# 0                                                 1504
# 1                                                 6476
# 2                                                 1880
# 3                                                 1054
# 4                                                 1148
# ..                                                 ...
# 100                                               3202
# 101                                                311
# 102                                               1562
# 103                                               1137
# 104                                               2163
#
#      Sex: All persons; Age: All categories: Age; General Health: All categories: General health; Religion: Hindu  \
# 0                                                 4528
# 1                                                32857
# 2                                                  856
# 3                                                 1078
# 4                                                 5131
# ..                                                 ...
# 100                                               5899
# 101                                                245
# 102                                               1157
# 103                                               1222
# 104                                               1562
#
#      Sex: All persons; Age: All categories: Age; General Health: All categories: General health; Religion: Jewish  \
# 0                                                 2442
# 1                                                 2801
# 2                                                  464
# 3                                                  148
# 4                                                  277
# ..                                                 ...
# 100                                               1067
# 101                                                 27
# 102                                                246
# 103                                                221
# 104                                                359
#
#      Sex: All persons; Age: All categories: Age; General Health: All categories: General health; Religion: Muslim  \
# 0                                                 7907
# 1                                               267511
# 2                                                 2238
# 3                                                75194
# 4                                               130111
# ..                                                 ...
# 100                                              26489
# 101                                                 84
# 102                                               3542
# 103                                               7672
# 104                                               7245
#
#      Sex: All persons; Age: All categories: Age; General Health: All categories: General health; Religion: Sikh  \
# 0                                                  675
# 1                                                61540
# 2                                                  204
# 3                                                  278
# 4                                                 5546
# ..                                                 ...
# 100                                               1756
# 101                                                 18
# 102                                                193
# 103                                                354
# 104                                                562
#
#      Sex: All persons; Age: All categories: Age; General Health: All categories: General health; Religion: Other religion  \
# 0                                                  939
# 1                                                 8872
# 2                                                 2917
# 3                                                 1350
# 4                                                 1890
# ..                                                 ...
# 100                                               3874
# 101                                                283
# 102                                               2007
# 103                                               1784
# 104                                               3582
#
#      Sex: All persons; Age: All categories: Age; General Health: All categories: General health; Religion: No religion  \
# 0                                                67263
# 1                                               386177
# 2                                               129285
# 3                                                86713
# 4                                               120858
# ..                                                 ...
# 100                                             359280
# 101                                              13758
# 102                                             146538
# 103                                             166810
# 104                                             227479
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 100  ...
# 101  ...
# 102  ...
# 103  ...
# 104  ...
#
#      Sex: Females; Age: Age 65 and over; General Health: Bad or very bad health; Religion: Christian  \
# 0                                                 2062
# 1                                                23871
# 2                                                 4537
# 3                                                 6240
# 4                                                 5506
# ..                                                 ...
# 100                                              15848
# 101                                                724
# 102                                               7859
# 103                                               8264
# 104                                              13526
#
#      Sex: Females; Age: Age 65 and over; General Health: Bad or very bad health; Religion: Buddhist  \
# 0                                                    3
# 1                                                   44
# 2                                                    6
# 3                                                    4
# 4                                                    6
# ..                                                 ...
# 100                                                 22
# 101                                                  0
# 102                                                 13
# 103                                                 12
# 104                                                 16
#
#      Sex: Females; Age: Age 65 and over; General Health: Bad or very bad health; Religion: Hindu  \
# 0                                                   18
# 1                                                  432
# 2                                                    3
# 3                                                   14
# 4                                                   64
# ..                                                 ...
# 100                                                 35
# 101                                                  0
# 102                                                  5
# 103                                                 11
# 104                                                  6
#
#      Sex: Females; Age: Age 65 and over; General Health: Bad or very bad health; Religion: Jewish  \
# 0                                                   12
# 1                                                   56
# 2                                                    8
# 3                                                    6
# 4                                                    8
# ..                                                 ...
# 100                                                 28
# 101                                                  0
# 102                                                  5
# 103                                                  1
# 104                                                  9
#
#      Sex: Females; Age: Age 65 and over; General Health: Bad or very bad health; Religion: Muslim  \
# 0                                                   52
# 1                                                 2395
# 2                                                    8
# 3                                                  590
# 4                                                 1014
# ..                                                 ...
# 100                                                197
# 101                                                  0
# 102                                                  8
# 103                                                 39
# 104                                                 25
#
#      Sex: Females; Age: Age 65 and over; General Health: Bad or very bad health; Religion: Sikh  \
# 0                                                    4
# 1                                                  968
# 2                                                    3
# 3                                                    4
# 4                                                   96
# ..                                                 ...
# 100                                                 13
# 101                                                  1
# 102                                                  0
# 103                                                  3
# 104                                                  2
#
#      Sex: Females; Age: Age 65 and over; General Health: Bad or very bad health; Religion: Other religion  \
# 0                                                    5
# 1                                                  101
# 2                                                   26
# 3                                                   21
# 4                                                   24
# ..                                                 ...
# 100                                                 63
# 101                                                  2
# 102                                                 26
# 103                                                 26
# 104                                                 38
#
#      Sex: Females; Age: Age 65 and over; General Health: Bad or very bad health; Religion: No religion  \
# 0                                                  163
# 1                                                 1364
# 2                                                  374
# 3                                                  321
# 4                                                  408
# ..                                                 ...
# 100                                               1847
# 101                                                 68
# 102                                                607
# 103                                                881
# 104                                               1227
#
#      Sex: Females; Age: Age 65 and over; General Health: Bad or very bad health; Religion: Religion not stated  \
# 0                                                  282
# 1                                                 2601
# 2                                                  550
# 3                                                  648
# 4                                                  732
# ..                                                 ...
# 100                                               2206
# 101                                                 78
# 102                                                973
# 103                                               1026
# 104                                               1661
#
#        Cluster
# 0    CLUSTER 2
# 1    CLUSTER 1
# 2    CLUSTER 0
# 3    CLUSTER 2
# 4    CLUSTER 1
# ..         ...
# 100  CLUSTER 1
# 101  CLUSTER 2
# 102  CLUSTER 0
# 103  CLUSTER 0
# 104  CLUSTER 1
#
# [105 rows x 602 columns]

# %%
def col_split(x : pd.Series):
    y = x['variable'].split(';')
    
    x['Sex'] = y[0]
    x['Age'] = y[1]
    x['General Health'] = y[2]
    x['Religion'] = y[3]
    
    return x

# %%
new_data = data.melt(id_vars=['geography', 'Cluster']).apply(col_split, axis = 1)
#data.melt(id_vars=['geography']).apply(col_split, axis = 1)

# %%
#Dropping the column 'variable' as it is of no use now.
new_data.drop('variable', axis=1, inplace=True)

# %%
#Removing the common name 'Sex: ' from 'Sex' column as it is of no use.
new_data['Sex'] =  new_data['Sex'].str.replace('Sex: ', '')

#Removing the common name 'Age: ' from 'Age' column as it is of no use.
new_data['Age'] =  new_data['Age'].str.replace('Age: ', '')

#Removing the common name 'General Health: ' from 'General Health' column as it is of no use.
new_data['General Health'] =  new_data['General Health'].str.replace('General Health: ', '')

#Removing the common name 'Religion: ' from 'Religion' column as it is of no use.
new_data['Religion'] =  new_data['Religion'].str.replace('Religion: ', '')

# %%
#bringing the 'value' column at the end of dataframe
new_data['Counts'] = new_data['value']
new_data.drop('value', axis=1, inplace=True)

# %%
new_data['Clusters'] = new_data['Cluster']
new_data.drop('Cluster', axis=1, inplace=True)

# %%
new_data[['area code', 'area name']] = new_data['geography'].str.split('-', 1, expand=True)

# %%
new_data
# Out:
#                     geography          Sex                   Age  \
# 0              AL - St Albans  All persons   All categories: Age
# 1              B - Birmingham  All persons   All categories: Age
# 2                   BA - Bath  All persons   All categories: Age
# 3              BB - Blackburn  All persons   All categories: Age
# 4               BD - Bradford  All persons   All categories: Age
# ...                       ...          ...                   ...
# 62995            CF - Cardiff      Females       Age 65 and over
# 62996  LD - Llandrindod Wells      Females       Age 65 and over
# 62997          LL - Llandudno      Females       Age 65 and over
# 62998            NP - Newport      Females       Age 65 and over
# 62999            SA - Swansea      Females       Age 65 and over
#
#                         General Health                   Religion   Counts  \
# 0       All categories: General health   All categories: Religion   250427
# 1       All categories: General health   All categories: Religion  1904658
# 2       All categories: General health   All categories: Religion   434166
# 3       All categories: General health   All categories: Religion   488917
# 4       All categories: General health   All categories: Religion   578336
# ...                                ...                        ...      ...
# 62995           Bad or very bad health        Religion not stated     2206
# 62996           Bad or very bad health        Religion not stated       78
# 62997           Bad or very bad health        Religion not stated      973
# 62998           Bad or very bad health        Religion not stated     1026
# 62999           Bad or very bad health        Religion not stated     1661
#
#         Clusters area code           area name
# 0      CLUSTER 2       AL            St Albans
# 1      CLUSTER 1        B           Birmingham
# 2      CLUSTER 0       BA                 Bath
# 3      CLUSTER 2       BB            Blackburn
# 4      CLUSTER 1       BD             Bradford
# ...          ...       ...                 ...
# 62995  CLUSTER 1       CF              Cardiff
# 62996  CLUSTER 2       LD    Llandrindod Wells
# 62997  CLUSTER 0       LL            Llandudno
# 62998  CLUSTER 0       NP              Newport
# 62999  CLUSTER 1       SA              Swansea
#
# [63000 rows x 9 columns]

# %%
new_data.to_csv('General Health by Religion and Sex GMM data.csv', index=False)
